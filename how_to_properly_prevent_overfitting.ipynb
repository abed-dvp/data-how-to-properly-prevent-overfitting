# %% [markdown]
# ## Imports

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler

# BLOB DATASET
from sklearn.datasets import make_blobs

# KERAS
from keras import Sequential, Input, layers, regularizers
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
# Out:
# 2026-05-14 12:40:00.433617: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-14 12:40:00.444608: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-14 12:40:00.571653: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-14 12:40:00.707520: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-14 12:40:00.860736: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-14 12:40:00.861574: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-14 12:40:01.071303: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-14 12:40:02.778672: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # How to Properly Prevent Overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %% [markdown]
# ## Data - the `blobs` Dataset

# %% [markdown]
# ### Generating a Blobs Dataset
#
# First, let's generate some data using the [`make_blobs`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate 2000 samples with 10 features each; there should be 8 classes of blobs (`centers` argument) with `cluster_std` equal to 7.

# %%
# YOUR CODE HERE
X, y = make_blobs(
    n_samples=2000,
    n_features=10,
    centers=8,
    cluster_std=7
)

# %% [markdown]
# ### Visualizing the Dataset
#
# All your samples have 10 features. Plot one of the dimensions against another.

# %%
# YOUR CODE HERE
plt.scatter(X[:,0],X[:, 1] , c=y)

# %% [markdown]
# ### Encoding your Categorical Target
#
# Use the 📚 [**to_categorical()**](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical) function to convert `y` to `y_cat`, which is the categorical representation of `y` with **One-Hot encoded** columns.

# %%
# YOUR CODE HERE
y_cat = to_categorical(y)

# %% [markdown]
# ## (1) Cross-Validation in Deep Learning
#
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a training set and a testing set at the beginning of the notebook. Then, we started to build different models which were trained on the training set and evaluated on the testing set.
#
# So, at the end of the day, we used the testing set every time we evaluated our models and different hyperparameters. This is normal: we always train on the training set and we evaluate on the testing set.
#
# However, we selected our "best model" based on the score of each model. In other words, we _used_ the test set to select our best model, which means there was ❗️ `data leakage` ❗️
#
# 🤔 **What should we do?**
#
# - A first good practice is to avoid using `random_state` or any deterministic separation between your training and testing sets. In that case, your testing set will change every time you re-run your notebook. This is far from being sufficient, though.
# - To compare models properly, you have to run a cross-validation, a 10-fold split, for instance.
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross -Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn, whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-validate a Neural Network**.

# %% [markdown]
# ### Designing a Neural Network
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - a `keras.Input` to pass the input shape
# - a first **hidden layer** with 25 neurons, the `relu` activation function
# - a second **hidden layer** with 10 neurons and the `relu` activation function.
# - a final **predictive layer** that is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss
# - the *Adam* optimizer
# - the *accuracy* metric

# %%
def initialize_model():
    model = Sequential()
    model.add(Input(shape=(10,)))
    model.add(layers.Dense(25, activation='relu'))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(8, activation='softmax'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# ### Cross-Validating the Neural Net
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the training data
# * 🧪 Evaluate your model on the testing data, and store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your training data before fitting the NN
# * 👌 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross-Validation, you are guided; just uncomment the following cell and follow the steps
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time, and we encourage you to do so whenever you run expensive computations

# %%
# %%time

kf = KFold(n_splits=10)
kf.get_n_splits(X)

results = []

for train_index, test_index in kf.split(X):
    #Split the data into train and test
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y_cat[train_index], y_cat[test_index]


#     # Scaling your data
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

#     # Initialize the model
    model = initialize_model()

#     # Fit the model on the train data
    model.fit(
        X_train_scaled,
        y_train,
        epochs=150,
        batch_size=16,
        verbose=0
    )

#     # Evaluate the model on the test data
    result = model.evaluate(X_test_scaled, y_test, verbose=0)

    results.append(result)

# %% [markdown]
# ### Performance of the Cross-Validated Network
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
accuracy = [_[1] for _ in results]

print(f'New mean accuracy: {np.mean(accuracy)*100:.2f}% (±{np.std(accuracy)*100:.2f})')
# Out:
# New mean accuracy: 77.00% (±2.30)

# %% [markdown]
# ### Remarks About the Computational Time
#
# - 🤯 You probably encountered one of the main drawbacks of using proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do **only one fold**.
# - 👮🏻‍♀️ Remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique.
# - 💼 In general, people split only once, as you did. Once they get to the end of their optimization, they launch a real cross-validation run at 6 PM, go home and get the final results on the next day.

# %% [markdown]
# ### Holdout Method
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a training set and a testing set with a 70/30% training-to-test data ratio.
#
# Make sure to also scale the data after splitting!

# %%
# YOUR CODE HERE
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_cat,
    test_size=0.3
)

# %%
# Scale the data
standard_scaler = StandardScaler()
standard_scaler.fit(X_train)

X_train_scaled = standard_scaler.transform(X_train)
X_test_scaled = standard_scaler.transform(X_test)

# %% [markdown]
# ## (2) How to Prevent a Neural Network from Overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 **Stop the learning process before overfitting**

# %% [markdown]
# #### Illustrating How a Neural Network Easily Overfits
#
# First things first, let's show that if we train the model for too long (= for too many epochs) it will overfit the training data and will not be good at predicting the testing data.
#
# **How can we do it without using the testing data, which is strictly forbidden?**
#
# You can use a fraction of the <font color=blue>training set</font> as a <font color=green>validation set</font>.
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/lectures/deep-learning/02/validation_set.png" width=450>
#
# With Keras, you don't have to re-use the `train_test_split` method from Scikit-Learn. Instead, you have two options:
#
# - `validation_split = 0.2` (for example): the last 20% of the observations in the training set will be used as the validation holdout set.
# - `validation_data = (X_val, y_val)` if you have access to a dataset that you want to use as the validation holdout set.
#
# 👉 Let's go with the first option and set `epochs = 500`.
#
# 👉 Store the performances of the model in a `history` variable.

# %%
# %%time
model = initialize_model()

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1
)# YOUR CODE HERE
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.1267 - loss: 2.0612 - val_accuracy: 0.1734 - val_loss: 2.0172
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3075 - loss: 1.9021 - val_accuracy: 0.3040 - val_loss: 1.8903
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4290 - loss: 1.7176 - val_accuracy: 0.4038 - val_loss: 1.7151
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5117 - loss: 1.4975 - val_accuracy: 0.4584 - val_loss: 1.5210
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5628 - loss: 1.2918 - val_accuracy: 0.5202 - val_loss: 1.3336
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6190 - loss: 1.1209 - val_accuracy: 0.5891 - val_loss: 1.1751
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6874 - loss: 0.9754 - val_accuracy: 0.6580 - val_loss: 1.0284
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7436 - loss: 0.8538 - val_accuracy: 0.7102 - val_loss: 0.9028
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7538 - loss: 0.7635 - val_accuracy: 0.7340 - val_loss: 0.8190
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.7043 - val_accuracy: 0.7458 - val_loss: 0.7579
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7743 - loss: 0.6641 - val_accuracy: 0.7553 - val_loss: 0.7141
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7855 - loss: 0.6358 - val_accuracy: 0.7696 - val_loss: 0.6854
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7896 - loss: 0.6143 - val_accuracy: 0.7791 - val_loss: 0.6595
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8029 - loss: 0.5931 - val_accuracy: 0.7933 - val_loss: 0.6399
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8008 - loss: 0.5800 - val_accuracy: 0.7933 - val_loss: 0.6232
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.5679 - val_accuracy: 0.7886 - val_loss: 0.6138
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8090 - loss: 0.5577 - val_accuracy: 0.7981 - val_loss: 0.6000
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8080 - loss: 0.5479 - val_accuracy: 0.7886 - val_loss: 0.5948
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8202 - loss: 0.5390 - val_accuracy: 0.8076 - val_loss: 0.5867
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8161 - loss: 0.5351 - val_accuracy: 0.8052 - val_loss: 0.5786
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8172 - loss: 0.5263 - val_accuracy: 0.7981 - val_loss: 0.5747
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8151 - loss: 0.5225 - val_accuracy: 0.8076 - val_loss: 0.5686
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8192 - loss: 0.5177 - val_accuracy: 0.8029 - val_loss: 0.5669
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8212 - loss: 0.5118 - val_accuracy: 0.8029 - val_loss: 0.5647
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8172 - loss: 0.5057 - val_accuracy: 0.8005 - val_loss: 0.5604
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8243 - loss: 0.5034 - val_accuracy: 0.8029 - val_loss: 0.5576
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8223 - loss: 0.5011 - val_accuracy: 0.8052 - val_loss: 0.5564
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8243 - loss: 0.4970 - val_accuracy: 0.8076 - val_loss: 0.5560
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8253 - loss: 0.4918 - val_accuracy: 0.8005 - val_loss: 0.5554
# Epoch 30/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8243 - loss: 0.4935 - val_accuracy: 0.8052 - val_loss: 0.5543
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8264 - loss: 0.4886 - val_accuracy: 0.8076 - val_loss: 0.5485
# Epoch 32/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8294 - loss: 0.4862 - val_accuracy: 0.8029 - val_loss: 0.5537
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8274 - loss: 0.4815 - val_accuracy: 0.8052 - val_loss: 0.5493
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8264 - loss: 0.4793 - val_accuracy: 0.8029 - val_loss: 0.5511
# Epoch 35/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8264 - loss: 0.4766 - val_accuracy: 0.8029 - val_loss: 0.5459
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8304 - loss: 0.4741 - val_accuracy: 0.8052 - val_loss: 0.5459
# Epoch 37/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8294 - loss: 0.4710 - val_accuracy: 0.8100 - val_loss: 0.5423
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8284 - loss: 0.4700 - val_accuracy: 0.8100 - val_loss: 0.5421
# Epoch 39/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8325 - loss: 0.4665 - val_accuracy: 0.8100 - val_loss: 0.5420
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8304 - loss: 0.4670 - val_accuracy: 0.8052 - val_loss: 0.5408
# Epoch 41/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8315 - loss: 0.4662 - val_accuracy: 0.8029 - val_loss: 0.5439
# Epoch 42/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8274 - loss: 0.4634 - val_accuracy: 0.8029 - val_loss: 0.5442
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8284 - loss: 0.4609 - val_accuracy: 0.8124 - val_loss: 0.5401
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4600 - val_accuracy: 0.8052 - val_loss: 0.5424
# Epoch 45/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8294 - loss: 0.4587 - val_accuracy: 0.8076 - val_loss: 0.5427
# Epoch 46/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8366 - loss: 0.4553 - val_accuracy: 0.8124 - val_loss: 0.5379
# Epoch 47/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8325 - loss: 0.4563 - val_accuracy: 0.8195 - val_loss: 0.5362
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8386 - loss: 0.4521 - val_accuracy: 0.8005 - val_loss: 0.5391
# Epoch 49/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8345 - loss: 0.4537 - val_accuracy: 0.8100 - val_loss: 0.5404
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8325 - loss: 0.4505 - val_accuracy: 0.8124 - val_loss: 0.5373
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8345 - loss: 0.4498 - val_accuracy: 0.8124 - val_loss: 0.5363
# Epoch 52/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8345 - loss: 0.4469 - val_accuracy: 0.8100 - val_loss: 0.5362
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8366 - loss: 0.4447 - val_accuracy: 0.8100 - val_loss: 0.5373
# Epoch 54/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8366 - loss: 0.4448 - val_accuracy: 0.8076 - val_loss: 0.5387
# Epoch 55/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8376 - loss: 0.4445 - val_accuracy: 0.8124 - val_loss: 0.5342
# Epoch 56/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8396 - loss: 0.4419 - val_accuracy: 0.8100 - val_loss: 0.5380
# Epoch 57/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8366 - loss: 0.4397 - val_accuracy: 0.8052 - val_loss: 0.5369
# Epoch 58/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8366 - loss: 0.4387 - val_accuracy: 0.8100 - val_loss: 0.5352
# Epoch 59/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8396 - loss: 0.4371 - val_accuracy: 0.8076 - val_loss: 0.5387
# Epoch 60/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8335 - loss: 0.4383 - val_accuracy: 0.8124 - val_loss: 0.5358
# Epoch 61/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8355 - loss: 0.4360 - val_accuracy: 0.8076 - val_loss: 0.5402
# Epoch 62/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8407 - loss: 0.4333 - val_accuracy: 0.8147 - val_loss: 0.5367
# Epoch 63/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8458 - loss: 0.4297 - val_accuracy: 0.8100 - val_loss: 0.5375
# Epoch 64/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8427 - loss: 0.4336 - val_accuracy: 0.8124 - val_loss: 0.5410
# Epoch 65/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8458 - loss: 0.4292 - val_accuracy: 0.8100 - val_loss: 0.5376
# Epoch 66/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8437 - loss: 0.4297 - val_accuracy: 0.8076 - val_loss: 0.5363
# Epoch 67/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.4266 - val_accuracy: 0.8100 - val_loss: 0.5366
# Epoch 68/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8458 - loss: 0.4264 - val_accuracy: 0.8147 - val_loss: 0.5374
# Epoch 69/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8396 - loss: 0.4276 - val_accuracy: 0.8052 - val_loss: 0.5367
# Epoch 70/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.4217 - val_accuracy: 0.8124 - val_loss: 0.5406
# Epoch 71/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8447 - loss: 0.4206 - val_accuracy: 0.8052 - val_loss: 0.5424
# Epoch 72/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8468 - loss: 0.4211 - val_accuracy: 0.8029 - val_loss: 0.5408
# Epoch 73/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.4170 - val_accuracy: 0.8076 - val_loss: 0.5457
# Epoch 74/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.4160 - val_accuracy: 0.8076 - val_loss: 0.5448
# Epoch 75/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8468 - loss: 0.4160 - val_accuracy: 0.8029 - val_loss: 0.5443
# Epoch 76/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8498 - loss: 0.4151 - val_accuracy: 0.8052 - val_loss: 0.5458
# Epoch 77/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8468 - loss: 0.4146 - val_accuracy: 0.8029 - val_loss: 0.5475
# Epoch 78/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8447 - loss: 0.4150 - val_accuracy: 0.8076 - val_loss: 0.5489
# Epoch 79/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.4120 - val_accuracy: 0.8124 - val_loss: 0.5490
# Epoch 80/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.4130 - val_accuracy: 0.8052 - val_loss: 0.5533
# Epoch 81/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8427 - loss: 0.4087 - val_accuracy: 0.8052 - val_loss: 0.5476
# Epoch 82/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8498 - loss: 0.4070 - val_accuracy: 0.8076 - val_loss: 0.5462
# Epoch 83/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8580 - loss: 0.4051 - val_accuracy: 0.8052 - val_loss: 0.5480
# Epoch 84/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.4053 - val_accuracy: 0.8005 - val_loss: 0.5503
# Epoch 85/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8601 - loss: 0.4047 - val_accuracy: 0.8076 - val_loss: 0.5500
# Epoch 86/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8529 - loss: 0.4010 - val_accuracy: 0.8100 - val_loss: 0.5485
# Epoch 87/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8550 - loss: 0.4021 - val_accuracy: 0.8029 - val_loss: 0.5521
# Epoch 88/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8601 - loss: 0.4000 - val_accuracy: 0.7981 - val_loss: 0.5571
# Epoch 89/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8580 - loss: 0.3981 - val_accuracy: 0.8029 - val_loss: 0.5541
# Epoch 90/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8570 - loss: 0.3963 - val_accuracy: 0.8029 - val_loss: 0.5546
# Epoch 91/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8580 - loss: 0.3973 - val_accuracy: 0.8147 - val_loss: 0.5554
# Epoch 92/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8590 - loss: 0.3962 - val_accuracy: 0.8124 - val_loss: 0.5598
# Epoch 93/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8611 - loss: 0.3949 - val_accuracy: 0.8100 - val_loss: 0.5566
# Epoch 94/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8560 - loss: 0.3953 - val_accuracy: 0.8147 - val_loss: 0.5525
# Epoch 95/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8580 - loss: 0.3938 - val_accuracy: 0.8005 - val_loss: 0.5583
# Epoch 96/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8560 - loss: 0.3917 - val_accuracy: 0.7981 - val_loss: 0.5607
# Epoch 97/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8621 - loss: 0.3899 - val_accuracy: 0.8076 - val_loss: 0.5638
# Epoch 98/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8652 - loss: 0.3888 - val_accuracy: 0.8100 - val_loss: 0.5619
# Epoch 99/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8672 - loss: 0.3863 - val_accuracy: 0.8029 - val_loss: 0.5630
# Epoch 100/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8601 - loss: 0.3857 - val_accuracy: 0.7981 - val_loss: 0.5670
# Epoch 101/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8611 - loss: 0.3852 - val_accuracy: 0.8076 - val_loss: 0.5682
# Epoch 102/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8611 - loss: 0.3849 - val_accuracy: 0.8124 - val_loss: 0.5670
# Epoch 103/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8621 - loss: 0.3820 - val_accuracy: 0.8052 - val_loss: 0.5662
# Epoch 104/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8672 - loss: 0.3846 - val_accuracy: 0.8100 - val_loss: 0.5681
# Epoch 105/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8631 - loss: 0.3815 - val_accuracy: 0.8076 - val_loss: 0.5715
# Epoch 106/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8601 - loss: 0.3782 - val_accuracy: 0.8029 - val_loss: 0.5744
# Epoch 107/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8703 - loss: 0.3781 - val_accuracy: 0.8029 - val_loss: 0.5749
# Epoch 108/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8621 - loss: 0.3774 - val_accuracy: 0.7981 - val_loss: 0.5771
# Epoch 109/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8733 - loss: 0.3748 - val_accuracy: 0.8029 - val_loss: 0.5785
# Epoch 110/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8652 - loss: 0.3807 - val_accuracy: 0.7933 - val_loss: 0.5777
# Epoch 111/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8723 - loss: 0.3742 - val_accuracy: 0.8029 - val_loss: 0.5792
# Epoch 112/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8672 - loss: 0.3729 - val_accuracy: 0.7981 - val_loss: 0.5817
# Epoch 113/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8703 - loss: 0.3725 - val_accuracy: 0.8005 - val_loss: 0.5825
# Epoch 114/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8682 - loss: 0.3698 - val_accuracy: 0.8029 - val_loss: 0.5844
# Epoch 115/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8723 - loss: 0.3693 - val_accuracy: 0.8052 - val_loss: 0.5838
# Epoch 116/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8784 - loss: 0.3665 - val_accuracy: 0.8005 - val_loss: 0.5852
# Epoch 117/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8754 - loss: 0.3668 - val_accuracy: 0.7957 - val_loss: 0.5831
# Epoch 118/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8744 - loss: 0.3661 - val_accuracy: 0.8005 - val_loss: 0.5857
# Epoch 119/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8713 - loss: 0.3657 - val_accuracy: 0.8029 - val_loss: 0.5880
# Epoch 120/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8703 - loss: 0.3640 - val_accuracy: 0.7981 - val_loss: 0.5884
# Epoch 121/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8733 - loss: 0.3631 - val_accuracy: 0.8005 - val_loss: 0.5910
# Epoch 122/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8754 - loss: 0.3617 - val_accuracy: 0.8076 - val_loss: 0.5949
# Epoch 123/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8703 - loss: 0.3604 - val_accuracy: 0.7981 - val_loss: 0.6038
# Epoch 124/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8693 - loss: 0.3627 - val_accuracy: 0.8029 - val_loss: 0.5978
# Epoch 125/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8784 - loss: 0.3596 - val_accuracy: 0.8005 - val_loss: 0.5996
# Epoch 126/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8836 - loss: 0.3590 - val_accuracy: 0.8029 - val_loss: 0.6011
# Epoch 127/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8744 - loss: 0.3570 - val_accuracy: 0.7910 - val_loss: 0.5995
# Epoch 128/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8754 - loss: 0.3565 - val_accuracy: 0.8005 - val_loss: 0.6044
# Epoch 129/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8774 - loss: 0.3586 - val_accuracy: 0.7933 - val_loss: 0.6078
# Epoch 130/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8764 - loss: 0.3555 - val_accuracy: 0.8052 - val_loss: 0.6085
# Epoch 131/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8856 - loss: 0.3537 - val_accuracy: 0.7957 - val_loss: 0.6081
# Epoch 132/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8805 - loss: 0.3509 - val_accuracy: 0.8005 - val_loss: 0.6098
# Epoch 133/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8805 - loss: 0.3514 - val_accuracy: 0.8052 - val_loss: 0.6083
# Epoch 134/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8795 - loss: 0.3492 - val_accuracy: 0.8052 - val_loss: 0.6103
# Epoch 135/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8774 - loss: 0.3513 - val_accuracy: 0.7981 - val_loss: 0.6127
# Epoch 136/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8815 - loss: 0.3492 - val_accuracy: 0.8005 - val_loss: 0.6150
# Epoch 137/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8815 - loss: 0.3465 - val_accuracy: 0.8052 - val_loss: 0.6128
# Epoch 138/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8795 - loss: 0.3479 - val_accuracy: 0.8076 - val_loss: 0.6118
# Epoch 139/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8836 - loss: 0.3454 - val_accuracy: 0.8005 - val_loss: 0.6188
# Epoch 140/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8795 - loss: 0.3438 - val_accuracy: 0.7981 - val_loss: 0.6176
# Epoch 141/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8825 - loss: 0.3435 - val_accuracy: 0.7957 - val_loss: 0.6228
# Epoch 142/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8866 - loss: 0.3427 - val_accuracy: 0.8029 - val_loss: 0.6191
# Epoch 143/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8836 - loss: 0.3438 - val_accuracy: 0.7981 - val_loss: 0.6226
# Epoch 144/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8795 - loss: 0.3419 - val_accuracy: 0.7957 - val_loss: 0.6300
# Epoch 145/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8846 - loss: 0.3392 - val_accuracy: 0.8052 - val_loss: 0.6265
# Epoch 146/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8846 - loss: 0.3385 - val_accuracy: 0.8005 - val_loss: 0.6306
# Epoch 147/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8856 - loss: 0.3396 - val_accuracy: 0.8029 - val_loss: 0.6323
# Epoch 148/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8856 - loss: 0.3390 - val_accuracy: 0.7933 - val_loss: 0.6292
# Epoch 149/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.3355 - val_accuracy: 0.7815 - val_loss: 0.6373
# Epoch 150/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8836 - loss: 0.3372 - val_accuracy: 0.7862 - val_loss: 0.6387
# Epoch 151/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.3341 - val_accuracy: 0.7981 - val_loss: 0.6332
# Epoch 152/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8887 - loss: 0.3335 - val_accuracy: 0.7933 - val_loss: 0.6388
# Epoch 153/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8876 - loss: 0.3323 - val_accuracy: 0.7886 - val_loss: 0.6401
# Epoch 154/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8846 - loss: 0.3321 - val_accuracy: 0.8005 - val_loss: 0.6441
# Epoch 155/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8876 - loss: 0.3318 - val_accuracy: 0.7910 - val_loss: 0.6461
# Epoch 156/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8917 - loss: 0.3306 - val_accuracy: 0.7933 - val_loss: 0.6480
# Epoch 157/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.3280 - val_accuracy: 0.7815 - val_loss: 0.6483
# Epoch 158/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8836 - loss: 0.3272 - val_accuracy: 0.7957 - val_loss: 0.6477
# Epoch 159/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8927 - loss: 0.3244 - val_accuracy: 0.7886 - val_loss: 0.6491
# Epoch 160/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8907 - loss: 0.3277 - val_accuracy: 0.7767 - val_loss: 0.6631
# Epoch 161/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8917 - loss: 0.3242 - val_accuracy: 0.7886 - val_loss: 0.6553
# Epoch 162/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8876 - loss: 0.3231 - val_accuracy: 0.7957 - val_loss: 0.6563
# Epoch 163/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8948 - loss: 0.3225 - val_accuracy: 0.7910 - val_loss: 0.6583
# Epoch 164/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.3236 - val_accuracy: 0.7838 - val_loss: 0.6622
# Epoch 165/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8887 - loss: 0.3209 - val_accuracy: 0.7791 - val_loss: 0.6637
# Epoch 166/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8897 - loss: 0.3210 - val_accuracy: 0.7815 - val_loss: 0.6619
# Epoch 167/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8927 - loss: 0.3217 - val_accuracy: 0.7910 - val_loss: 0.6615
# Epoch 168/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8907 - loss: 0.3171 - val_accuracy: 0.7910 - val_loss: 0.6703
# Epoch 169/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8938 - loss: 0.3185 - val_accuracy: 0.7886 - val_loss: 0.6765
# Epoch 170/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.3172 - val_accuracy: 0.7862 - val_loss: 0.6755
# Epoch 171/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.3167 - val_accuracy: 0.7886 - val_loss: 0.6716
# Epoch 172/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.3153 - val_accuracy: 0.7862 - val_loss: 0.6772
# Epoch 173/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8958 - loss: 0.3166 - val_accuracy: 0.7838 - val_loss: 0.6820
# Epoch 174/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8907 - loss: 0.3162 - val_accuracy: 0.7815 - val_loss: 0.6853
# Epoch 175/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.3134 - val_accuracy: 0.7886 - val_loss: 0.6847
# Epoch 176/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 0.3114 - val_accuracy: 0.7791 - val_loss: 0.6908
# Epoch 177/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8979 - loss: 0.3105 - val_accuracy: 0.7815 - val_loss: 0.6870
# Epoch 178/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8938 - loss: 0.3123 - val_accuracy: 0.7815 - val_loss: 0.6939
# Epoch 179/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8948 - loss: 0.3094 - val_accuracy: 0.7672 - val_loss: 0.6975
# Epoch 180/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8958 - loss: 0.3090 - val_accuracy: 0.7696 - val_loss: 0.6988
# Epoch 181/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8887 - loss: 0.3080 - val_accuracy: 0.7696 - val_loss: 0.7035
# Epoch 182/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8958 - loss: 0.3086 - val_accuracy: 0.7743 - val_loss: 0.7012
# Epoch 183/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8989 - loss: 0.3058 - val_accuracy: 0.7791 - val_loss: 0.7016
# Epoch 184/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8927 - loss: 0.3069 - val_accuracy: 0.7791 - val_loss: 0.7062
# Epoch 185/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8979 - loss: 0.3068 - val_accuracy: 0.7838 - val_loss: 0.7025
# Epoch 186/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8938 - loss: 0.3041 - val_accuracy: 0.7720 - val_loss: 0.7091
# Epoch 187/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8938 - loss: 0.3051 - val_accuracy: 0.7696 - val_loss: 0.7096
# Epoch 188/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8938 - loss: 0.3058 - val_accuracy: 0.7862 - val_loss: 0.7142
# Epoch 189/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8979 - loss: 0.3022 - val_accuracy: 0.7648 - val_loss: 0.7161
# Epoch 190/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8948 - loss: 0.3021 - val_accuracy: 0.7625 - val_loss: 0.7186
# Epoch 191/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8938 - loss: 0.3021 - val_accuracy: 0.7720 - val_loss: 0.7213
# Epoch 192/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 0.3009 - val_accuracy: 0.7767 - val_loss: 0.7156
# Epoch 193/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8968 - loss: 0.3002 - val_accuracy: 0.7767 - val_loss: 0.7240
# Epoch 194/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8979 - loss: 0.2988 - val_accuracy: 0.7601 - val_loss: 0.7269
# Epoch 195/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8948 - loss: 0.2965 - val_accuracy: 0.7530 - val_loss: 0.7295
# Epoch 196/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8968 - loss: 0.2977 - val_accuracy: 0.7625 - val_loss: 0.7355
# Epoch 197/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8979 - loss: 0.2987 - val_accuracy: 0.7601 - val_loss: 0.7303
# Epoch 198/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8938 - loss: 0.2994 - val_accuracy: 0.7530 - val_loss: 0.7401
# Epoch 199/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9019 - loss: 0.2948 - val_accuracy: 0.7672 - val_loss: 0.7323
# Epoch 200/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8968 - loss: 0.2927 - val_accuracy: 0.7648 - val_loss: 0.7397
# Epoch 201/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9019 - loss: 0.2952 - val_accuracy: 0.7601 - val_loss: 0.7433
# Epoch 202/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8979 - loss: 0.2956 - val_accuracy: 0.7767 - val_loss: 0.7405
# Epoch 203/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8927 - loss: 0.2908 - val_accuracy: 0.7696 - val_loss: 0.7505
# Epoch 204/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9030 - loss: 0.2909 - val_accuracy: 0.7482 - val_loss: 0.7560
# Epoch 205/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 0.2916 - val_accuracy: 0.7577 - val_loss: 0.7509
# Epoch 206/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8989 - loss: 0.2910 - val_accuracy: 0.7506 - val_loss: 0.7540
# Epoch 207/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8989 - loss: 0.2901 - val_accuracy: 0.7696 - val_loss: 0.7502
# Epoch 208/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8979 - loss: 0.2912 - val_accuracy: 0.7530 - val_loss: 0.7612
# Epoch 209/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9040 - loss: 0.2864 - val_accuracy: 0.7577 - val_loss: 0.7627
# Epoch 210/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 0.2896 - val_accuracy: 0.7601 - val_loss: 0.7592
# Epoch 211/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9070 - loss: 0.2868 - val_accuracy: 0.7601 - val_loss: 0.7554
# Epoch 212/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8968 - loss: 0.2874 - val_accuracy: 0.7553 - val_loss: 0.7630
# Epoch 213/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9050 - loss: 0.2861 - val_accuracy: 0.7506 - val_loss: 0.7680
# Epoch 214/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9019 - loss: 0.2859 - val_accuracy: 0.7601 - val_loss: 0.7593
# Epoch 215/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9060 - loss: 0.2857 - val_accuracy: 0.7577 - val_loss: 0.7681
# Epoch 216/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8999 - loss: 0.2851 - val_accuracy: 0.7530 - val_loss: 0.7735
# Epoch 217/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9040 - loss: 0.2852 - val_accuracy: 0.7577 - val_loss: 0.7738
# Epoch 218/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9030 - loss: 0.2820 - val_accuracy: 0.7530 - val_loss: 0.7761
# Epoch 219/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8999 - loss: 0.2818 - val_accuracy: 0.7601 - val_loss: 0.7748
# Epoch 220/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9111 - loss: 0.2832 - val_accuracy: 0.7553 - val_loss: 0.7845
# Epoch 221/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9009 - loss: 0.2823 - val_accuracy: 0.7458 - val_loss: 0.7930
# Epoch 222/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9091 - loss: 0.2802 - val_accuracy: 0.7601 - val_loss: 0.7858
# Epoch 223/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9030 - loss: 0.2798 - val_accuracy: 0.7553 - val_loss: 0.7830
# Epoch 224/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9122 - loss: 0.2785 - val_accuracy: 0.7506 - val_loss: 0.7895
# Epoch 225/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9070 - loss: 0.2762 - val_accuracy: 0.7506 - val_loss: 0.7879
# Epoch 226/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9111 - loss: 0.2760 - val_accuracy: 0.7553 - val_loss: 0.7921
# Epoch 227/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9111 - loss: 0.2746 - val_accuracy: 0.7553 - val_loss: 0.7925
# Epoch 228/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9101 - loss: 0.2754 - val_accuracy: 0.7530 - val_loss: 0.7963
# Epoch 229/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9019 - loss: 0.2766 - val_accuracy: 0.7530 - val_loss: 0.7982
# Epoch 230/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9111 - loss: 0.2734 - val_accuracy: 0.7601 - val_loss: 0.8015
# Epoch 231/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9091 - loss: 0.2728 - val_accuracy: 0.7411 - val_loss: 0.8139
# Epoch 232/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9091 - loss: 0.2729 - val_accuracy: 0.7506 - val_loss: 0.8103
# Epoch 233/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9060 - loss: 0.2740 - val_accuracy: 0.7506 - val_loss: 0.8121
# Epoch 234/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9060 - loss: 0.2733 - val_accuracy: 0.7506 - val_loss: 0.8166
# Epoch 235/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9152 - loss: 0.2697 - val_accuracy: 0.7506 - val_loss: 0.8152
# Epoch 236/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9081 - loss: 0.2717 - val_accuracy: 0.7553 - val_loss: 0.8177
# Epoch 237/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9050 - loss: 0.2693 - val_accuracy: 0.7506 - val_loss: 0.8181
# Epoch 238/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9122 - loss: 0.2695 - val_accuracy: 0.7506 - val_loss: 0.8243
# Epoch 239/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9122 - loss: 0.2686 - val_accuracy: 0.7482 - val_loss: 0.8279
# Epoch 240/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9132 - loss: 0.2681 - val_accuracy: 0.7482 - val_loss: 0.8235
# Epoch 241/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9101 - loss: 0.2676 - val_accuracy: 0.7506 - val_loss: 0.8281
# Epoch 242/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9122 - loss: 0.2652 - val_accuracy: 0.7435 - val_loss: 0.8373
# Epoch 243/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9162 - loss: 0.2679 - val_accuracy: 0.7482 - val_loss: 0.8384
# Epoch 244/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9132 - loss: 0.2638 - val_accuracy: 0.7625 - val_loss: 0.8299
# Epoch 245/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9101 - loss: 0.2657 - val_accuracy: 0.7577 - val_loss: 0.8333
# Epoch 246/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9142 - loss: 0.2630 - val_accuracy: 0.7458 - val_loss: 0.8427
# Epoch 247/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9070 - loss: 0.2650 - val_accuracy: 0.7482 - val_loss: 0.8446
# Epoch 248/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9122 - loss: 0.2623 - val_accuracy: 0.7530 - val_loss: 0.8420
# Epoch 249/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9101 - loss: 0.2652 - val_accuracy: 0.7530 - val_loss: 0.8453
# Epoch 250/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9142 - loss: 0.2619 - val_accuracy: 0.7625 - val_loss: 0.8525
# Epoch 251/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9173 - loss: 0.2620 - val_accuracy: 0.7435 - val_loss: 0.8548
# Epoch 252/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9122 - loss: 0.2604 - val_accuracy: 0.7458 - val_loss: 0.8521
# Epoch 253/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9132 - loss: 0.2593 - val_accuracy: 0.7482 - val_loss: 0.8511
# Epoch 254/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9162 - loss: 0.2603 - val_accuracy: 0.7506 - val_loss: 0.8565
# Epoch 255/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9122 - loss: 0.2564 - val_accuracy: 0.7482 - val_loss: 0.8555
# Epoch 256/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9132 - loss: 0.2575 - val_accuracy: 0.7482 - val_loss: 0.8572
# Epoch 257/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9111 - loss: 0.2571 - val_accuracy: 0.7506 - val_loss: 0.8630
# Epoch 258/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9101 - loss: 0.2564 - val_accuracy: 0.7435 - val_loss: 0.8645
# Epoch 259/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9101 - loss: 0.2563 - val_accuracy: 0.7506 - val_loss: 0.8600
# Epoch 260/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9132 - loss: 0.2558 - val_accuracy: 0.7458 - val_loss: 0.8718
# Epoch 261/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9173 - loss: 0.2550 - val_accuracy: 0.7458 - val_loss: 0.8665
# Epoch 262/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9173 - loss: 0.2533 - val_accuracy: 0.7482 - val_loss: 0.8734
# Epoch 263/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9203 - loss: 0.2531 - val_accuracy: 0.7435 - val_loss: 0.8740
# Epoch 264/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9142 - loss: 0.2530 - val_accuracy: 0.7411 - val_loss: 0.8779
# Epoch 265/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9122 - loss: 0.2517 - val_accuracy: 0.7506 - val_loss: 0.8752
# Epoch 266/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9203 - loss: 0.2513 - val_accuracy: 0.7458 - val_loss: 0.8839
# Epoch 267/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9173 - loss: 0.2528 - val_accuracy: 0.7482 - val_loss: 0.8806
# Epoch 268/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9162 - loss: 0.2506 - val_accuracy: 0.7482 - val_loss: 0.8867
# Epoch 269/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9173 - loss: 0.2478 - val_accuracy: 0.7482 - val_loss: 0.8903
# Epoch 270/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9213 - loss: 0.2488 - val_accuracy: 0.7482 - val_loss: 0.8821
# Epoch 271/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9173 - loss: 0.2489 - val_accuracy: 0.7363 - val_loss: 0.8979
# Epoch 272/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9244 - loss: 0.2490 - val_accuracy: 0.7435 - val_loss: 0.8882
# Epoch 273/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9162 - loss: 0.2490 - val_accuracy: 0.7553 - val_loss: 0.8972
# Epoch 274/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9162 - loss: 0.2496 - val_accuracy: 0.7435 - val_loss: 0.8917
# Epoch 275/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9224 - loss: 0.2471 - val_accuracy: 0.7506 - val_loss: 0.8955
# Epoch 276/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9173 - loss: 0.2465 - val_accuracy: 0.7458 - val_loss: 0.8961
# Epoch 277/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9142 - loss: 0.2440 - val_accuracy: 0.7458 - val_loss: 0.9037
# Epoch 278/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9183 - loss: 0.2443 - val_accuracy: 0.7435 - val_loss: 0.9138
# Epoch 279/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9234 - loss: 0.2426 - val_accuracy: 0.7506 - val_loss: 0.9066
# Epoch 280/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9224 - loss: 0.2433 - val_accuracy: 0.7435 - val_loss: 0.9158
# Epoch 281/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9162 - loss: 0.2438 - val_accuracy: 0.7506 - val_loss: 0.9086
# Epoch 282/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9244 - loss: 0.2413 - val_accuracy: 0.7482 - val_loss: 0.9142
# Epoch 283/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9213 - loss: 0.2401 - val_accuracy: 0.7530 - val_loss: 0.9131
# Epoch 284/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9193 - loss: 0.2434 - val_accuracy: 0.7530 - val_loss: 0.9115
# Epoch 285/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9213 - loss: 0.2410 - val_accuracy: 0.7458 - val_loss: 0.9179
# Epoch 286/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9265 - loss: 0.2390 - val_accuracy: 0.7435 - val_loss: 0.9227
# Epoch 287/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9224 - loss: 0.2389 - val_accuracy: 0.7530 - val_loss: 0.9186
# Epoch 288/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9213 - loss: 0.2399 - val_accuracy: 0.7530 - val_loss: 0.9220
# Epoch 289/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9224 - loss: 0.2361 - val_accuracy: 0.7506 - val_loss: 0.9218
# Epoch 290/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9254 - loss: 0.2370 - val_accuracy: 0.7506 - val_loss: 0.9301
# Epoch 291/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9183 - loss: 0.2387 - val_accuracy: 0.7530 - val_loss: 0.9284
# Epoch 292/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9275 - loss: 0.2366 - val_accuracy: 0.7482 - val_loss: 0.9276
# Epoch 293/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9203 - loss: 0.2358 - val_accuracy: 0.7458 - val_loss: 0.9266
# Epoch 294/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9295 - loss: 0.2354 - val_accuracy: 0.7435 - val_loss: 0.9356
# Epoch 295/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9234 - loss: 0.2349 - val_accuracy: 0.7506 - val_loss: 0.9319
# Epoch 296/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9305 - loss: 0.2326 - val_accuracy: 0.7482 - val_loss: 0.9348
# Epoch 297/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9244 - loss: 0.2327 - val_accuracy: 0.7506 - val_loss: 0.9437
# Epoch 298/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9254 - loss: 0.2324 - val_accuracy: 0.7530 - val_loss: 0.9367
# Epoch 299/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9203 - loss: 0.2304 - val_accuracy: 0.7506 - val_loss: 0.9404
# Epoch 300/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9326 - loss: 0.2280 - val_accuracy: 0.7506 - val_loss: 0.9420
# Epoch 301/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.2301 - val_accuracy: 0.7553 - val_loss: 0.9419
# Epoch 302/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.2274 - val_accuracy: 0.7506 - val_loss: 0.9413
# Epoch 303/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9265 - loss: 0.2287 - val_accuracy: 0.7530 - val_loss: 0.9515
# Epoch 304/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9265 - loss: 0.2263 - val_accuracy: 0.7553 - val_loss: 0.9500
# Epoch 305/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9326 - loss: 0.2306 - val_accuracy: 0.7506 - val_loss: 0.9602
# Epoch 306/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9285 - loss: 0.2268 - val_accuracy: 0.7553 - val_loss: 0.9613
# Epoch 307/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9224 - loss: 0.2339 - val_accuracy: 0.7506 - val_loss: 0.9617
# Epoch 308/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9234 - loss: 0.2251 - val_accuracy: 0.7458 - val_loss: 0.9645
# Epoch 309/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9285 - loss: 0.2239 - val_accuracy: 0.7530 - val_loss: 0.9627
# Epoch 310/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9285 - loss: 0.2250 - val_accuracy: 0.7482 - val_loss: 0.9565
# Epoch 311/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9213 - loss: 0.2271 - val_accuracy: 0.7553 - val_loss: 0.9577
# Epoch 312/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9234 - loss: 0.2227 - val_accuracy: 0.7530 - val_loss: 0.9731
# Epoch 313/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9305 - loss: 0.2192 - val_accuracy: 0.7530 - val_loss: 0.9646
# Epoch 314/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.2205 - val_accuracy: 0.7482 - val_loss: 0.9726
# Epoch 315/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9326 - loss: 0.2188 - val_accuracy: 0.7482 - val_loss: 0.9740
# Epoch 316/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9336 - loss: 0.2217 - val_accuracy: 0.7553 - val_loss: 0.9630
# Epoch 317/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.2206 - val_accuracy: 0.7530 - val_loss: 0.9699
# Epoch 318/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9244 - loss: 0.2198 - val_accuracy: 0.7530 - val_loss: 0.9794
# Epoch 319/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9326 - loss: 0.2156 - val_accuracy: 0.7506 - val_loss: 0.9782
# Epoch 320/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9356 - loss: 0.2190 - val_accuracy: 0.7506 - val_loss: 0.9790
# Epoch 321/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.2166 - val_accuracy: 0.7506 - val_loss: 0.9808
# Epoch 322/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.2169 - val_accuracy: 0.7553 - val_loss: 0.9796
# Epoch 323/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9316 - loss: 0.2138 - val_accuracy: 0.7482 - val_loss: 0.9846
# Epoch 324/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9326 - loss: 0.2157 - val_accuracy: 0.7506 - val_loss: 0.9877
# Epoch 325/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9356 - loss: 0.2145 - val_accuracy: 0.7482 - val_loss: 1.0016
# Epoch 326/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9336 - loss: 0.2126 - val_accuracy: 0.7482 - val_loss: 0.9886
# Epoch 327/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9326 - loss: 0.2109 - val_accuracy: 0.7553 - val_loss: 0.9876
# Epoch 328/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.2116 - val_accuracy: 0.7482 - val_loss: 0.9949
# Epoch 329/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.2147 - val_accuracy: 0.7506 - val_loss: 0.9993
# Epoch 330/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9356 - loss: 0.2107 - val_accuracy: 0.7530 - val_loss: 1.0049
# Epoch 331/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9295 - loss: 0.2134 - val_accuracy: 0.7506 - val_loss: 0.9965
# Epoch 332/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9356 - loss: 0.2116 - val_accuracy: 0.7553 - val_loss: 0.9937
# Epoch 333/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9377 - loss: 0.2085 - val_accuracy: 0.7482 - val_loss: 1.0046
# Epoch 334/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9346 - loss: 0.2087 - val_accuracy: 0.7553 - val_loss: 1.0069
# Epoch 335/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9326 - loss: 0.2084 - val_accuracy: 0.7482 - val_loss: 1.0061
# Epoch 336/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9408 - loss: 0.2062 - val_accuracy: 0.7482 - val_loss: 1.0132
# Epoch 337/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9367 - loss: 0.2056 - val_accuracy: 0.7577 - val_loss: 1.0100
# Epoch 338/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9326 - loss: 0.2079 - val_accuracy: 0.7482 - val_loss: 1.0188
# Epoch 339/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9346 - loss: 0.2059 - val_accuracy: 0.7482 - val_loss: 1.0268
# Epoch 340/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9305 - loss: 0.2063 - val_accuracy: 0.7530 - val_loss: 1.0149
# Epoch 341/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.2055 - val_accuracy: 0.7530 - val_loss: 1.0236
# Epoch 342/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9336 - loss: 0.2030 - val_accuracy: 0.7506 - val_loss: 1.0292
# Epoch 343/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9377 - loss: 0.2023 - val_accuracy: 0.7506 - val_loss: 1.0255
# Epoch 344/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9377 - loss: 0.2043 - val_accuracy: 0.7553 - val_loss: 1.0290
# Epoch 345/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.2020 - val_accuracy: 0.7506 - val_loss: 1.0310
# Epoch 346/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9356 - loss: 0.2033 - val_accuracy: 0.7530 - val_loss: 1.0364
# Epoch 347/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9356 - loss: 0.2005 - val_accuracy: 0.7482 - val_loss: 1.0421
# Epoch 348/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.2013 - val_accuracy: 0.7482 - val_loss: 1.0411
# Epoch 349/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.2063 - val_accuracy: 0.7458 - val_loss: 1.0469
# Epoch 350/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9305 - loss: 0.2027 - val_accuracy: 0.7506 - val_loss: 1.0438
# Epoch 351/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.2025 - val_accuracy: 0.7458 - val_loss: 1.0488
# Epoch 352/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9397 - loss: 0.1978 - val_accuracy: 0.7458 - val_loss: 1.0490
# Epoch 353/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9397 - loss: 0.1994 - val_accuracy: 0.7482 - val_loss: 1.0601
# Epoch 354/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9397 - loss: 0.1982 - val_accuracy: 0.7506 - val_loss: 1.0502
# Epoch 355/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.1979 - val_accuracy: 0.7458 - val_loss: 1.0576
# Epoch 356/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9438 - loss: 0.1981 - val_accuracy: 0.7435 - val_loss: 1.0520
# Epoch 357/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9387 - loss: 0.1962 - val_accuracy: 0.7482 - val_loss: 1.0770
# Epoch 358/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1959 - val_accuracy: 0.7387 - val_loss: 1.0687
# Epoch 359/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1961 - val_accuracy: 0.7482 - val_loss: 1.0601
# Epoch 360/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.1943 - val_accuracy: 0.7506 - val_loss: 1.0647
# Epoch 361/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1941 - val_accuracy: 0.7482 - val_loss: 1.0670
# Epoch 362/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9387 - loss: 0.1945 - val_accuracy: 0.7506 - val_loss: 1.0722
# Epoch 363/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9377 - loss: 0.1950 - val_accuracy: 0.7482 - val_loss: 1.0712
# Epoch 364/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.1930 - val_accuracy: 0.7411 - val_loss: 1.0871
# Epoch 365/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1922 - val_accuracy: 0.7458 - val_loss: 1.0781
# Epoch 366/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9387 - loss: 0.1913 - val_accuracy: 0.7506 - val_loss: 1.0859
# Epoch 367/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1906 - val_accuracy: 0.7530 - val_loss: 1.0913
# Epoch 368/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9438 - loss: 0.1912 - val_accuracy: 0.7482 - val_loss: 1.0881
# Epoch 369/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9408 - loss: 0.1922 - val_accuracy: 0.7411 - val_loss: 1.1025
# Epoch 370/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9387 - loss: 0.1917 - val_accuracy: 0.7411 - val_loss: 1.1006
# Epoch 371/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1897 - val_accuracy: 0.7482 - val_loss: 1.0991
# Epoch 372/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9448 - loss: 0.1880 - val_accuracy: 0.7387 - val_loss: 1.1044
# Epoch 373/500
# ...
# Epoch 378/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9469 - loss: 0.1863 - val_accuracy: 0.7458 - val_loss: 1.1328
# Epoch 379/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9438 - loss: 0.1855 - val_accuracy: 0.7411 - val_loss: 1.1219
# Epoch 380/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9459 - loss: 0.1878 - val_accuracy: 0.7458 - val_loss: 1.1316
# Epoch 381/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9459 - loss: 0.1853 - val_accuracy: 0.7435 - val_loss: 1.1317
# Epoch 382/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1848 - val_accuracy: 0.7411 - val_loss: 1.1351
# Epoch 383/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9469 - loss: 0.1830 - val_accuracy: 0.7482 - val_loss: 1.1340
# Epoch 384/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9459 - loss: 0.1850 - val_accuracy: 0.7411 - val_loss: 1.1410
# Epoch 385/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9469 - loss: 0.1834 - val_accuracy: 0.7363 - val_loss: 1.1373
# Epoch 386/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9448 - loss: 0.1820 - val_accuracy: 0.7506 - val_loss: 1.1478
# Epoch 387/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9479 - loss: 0.1828 - val_accuracy: 0.7458 - val_loss: 1.1408
# Epoch 388/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9479 - loss: 0.1833 - val_accuracy: 0.7411 - val_loss: 1.1469
# Epoch 389/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9397 - loss: 0.1863 - val_accuracy: 0.7506 - val_loss: 1.1527
# Epoch 390/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9469 - loss: 0.1848 - val_accuracy: 0.7435 - val_loss: 1.1708
# Epoch 391/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9479 - loss: 0.1816 - val_accuracy: 0.7435 - val_loss: 1.1543
# Epoch 392/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9479 - loss: 0.1796 - val_accuracy: 0.7482 - val_loss: 1.1671
# Epoch 393/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9459 - loss: 0.1809 - val_accuracy: 0.7435 - val_loss: 1.1686
# Epoch 394/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9428 - loss: 0.1816 - val_accuracy: 0.7387 - val_loss: 1.1700
# Epoch 395/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9489 - loss: 0.1774 - val_accuracy: 0.7411 - val_loss: 1.1680
# Epoch 396/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9530 - loss: 0.1801 - val_accuracy: 0.7411 - val_loss: 1.1656
# Epoch 397/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9469 - loss: 0.1774 - val_accuracy: 0.7435 - val_loss: 1.1864
# Epoch 398/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9489 - loss: 0.1797 - val_accuracy: 0.7387 - val_loss: 1.1757
# Epoch 399/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9510 - loss: 0.1746 - val_accuracy: 0.7387 - val_loss: 1.1870
# Epoch 400/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9397 - loss: 0.1787 - val_accuracy: 0.7411 - val_loss: 1.1805
# Epoch 401/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9510 - loss: 0.1756 - val_accuracy: 0.7363 - val_loss: 1.1952
# Epoch 402/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9469 - loss: 0.1757 - val_accuracy: 0.7530 - val_loss: 1.1867
# Epoch 403/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9438 - loss: 0.1741 - val_accuracy: 0.7387 - val_loss: 1.1987
# Epoch 404/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9479 - loss: 0.1757 - val_accuracy: 0.7458 - val_loss: 1.1905
# Epoch 405/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9459 - loss: 0.1754 - val_accuracy: 0.7482 - val_loss: 1.1991
# Epoch 406/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9459 - loss: 0.1743 - val_accuracy: 0.7411 - val_loss: 1.2096
# Epoch 407/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9499 - loss: 0.1723 - val_accuracy: 0.7363 - val_loss: 1.2069
# Epoch 408/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9510 - loss: 0.1747 - val_accuracy: 0.7411 - val_loss: 1.2109
# Epoch 409/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9469 - loss: 0.1709 - val_accuracy: 0.7411 - val_loss: 1.2043
# Epoch 410/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9530 - loss: 0.1733 - val_accuracy: 0.7458 - val_loss: 1.2110
# Epoch 411/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.1716 - val_accuracy: 0.7316 - val_loss: 1.2172
# Epoch 412/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9510 - loss: 0.1729 - val_accuracy: 0.7435 - val_loss: 1.2160
# Epoch 413/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9489 - loss: 0.1737 - val_accuracy: 0.7411 - val_loss: 1.2268
# Epoch 414/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9489 - loss: 0.1713 - val_accuracy: 0.7506 - val_loss: 1.2153
# Epoch 415/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9479 - loss: 0.1753 - val_accuracy: 0.7387 - val_loss: 1.2322
# Epoch 416/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9540 - loss: 0.1706 - val_accuracy: 0.7482 - val_loss: 1.2351
# Epoch 417/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1752 - val_accuracy: 0.7340 - val_loss: 1.2421
# Epoch 418/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9448 - loss: 0.1749 - val_accuracy: 0.7387 - val_loss: 1.2301
# Epoch 419/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 0.1688 - val_accuracy: 0.7363 - val_loss: 1.2340
# Epoch 420/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 0.1688 - val_accuracy: 0.7435 - val_loss: 1.2369
# Epoch 421/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9479 - loss: 0.1668 - val_accuracy: 0.7387 - val_loss: 1.2525
# Epoch 422/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9551 - loss: 0.1689 - val_accuracy: 0.7363 - val_loss: 1.2459
# Epoch 423/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9540 - loss: 0.1673 - val_accuracy: 0.7340 - val_loss: 1.2574
# Epoch 424/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.1660 - val_accuracy: 0.7387 - val_loss: 1.2504
# Epoch 425/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 0.1668 - val_accuracy: 0.7387 - val_loss: 1.2649
# Epoch 426/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9489 - loss: 0.1719 - val_accuracy: 0.7387 - val_loss: 1.2558
# Epoch 427/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.1658 - val_accuracy: 0.7435 - val_loss: 1.2643
# Epoch 428/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1657 - val_accuracy: 0.7363 - val_loss: 1.2668
# Epoch 429/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9551 - loss: 0.1651 - val_accuracy: 0.7482 - val_loss: 1.2665
# Epoch 430/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.1648 - val_accuracy: 0.7411 - val_loss: 1.2720
# Epoch 431/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 0.1649 - val_accuracy: 0.7292 - val_loss: 1.2843
# Epoch 432/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1639 - val_accuracy: 0.7363 - val_loss: 1.2731
# Epoch 433/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9520 - loss: 0.1640 - val_accuracy: 0.7340 - val_loss: 1.2841
# Epoch 434/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 0.1630 - val_accuracy: 0.7340 - val_loss: 1.2918
# Epoch 435/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9540 - loss: 0.1647 - val_accuracy: 0.7458 - val_loss: 1.2839
# Epoch 436/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1608 - val_accuracy: 0.7482 - val_loss: 1.2872
# Epoch 437/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1614 - val_accuracy: 0.7340 - val_loss: 1.2897
# Epoch 438/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.1614 - val_accuracy: 0.7458 - val_loss: 1.2898
# Epoch 439/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.1635 - val_accuracy: 0.7316 - val_loss: 1.2986
# Epoch 440/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.1620 - val_accuracy: 0.7340 - val_loss: 1.3026
# Epoch 441/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1595 - val_accuracy: 0.7387 - val_loss: 1.3044
# Epoch 442/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9551 - loss: 0.1594 - val_accuracy: 0.7387 - val_loss: 1.3066
# Epoch 443/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.1593 - val_accuracy: 0.7435 - val_loss: 1.3014
# Epoch 444/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9510 - loss: 0.1614 - val_accuracy: 0.7363 - val_loss: 1.3201
# Epoch 445/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1591 - val_accuracy: 0.7387 - val_loss: 1.3101
# Epoch 446/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1585 - val_accuracy: 0.7340 - val_loss: 1.3203
# Epoch 447/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1584 - val_accuracy: 0.7245 - val_loss: 1.3326
# Epoch 448/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9551 - loss: 0.1615 - val_accuracy: 0.7292 - val_loss: 1.3352
# Epoch 449/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.1609 - val_accuracy: 0.7387 - val_loss: 1.3234
# Epoch 450/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9622 - loss: 0.1571 - val_accuracy: 0.7458 - val_loss: 1.3337
# Epoch 451/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1557 - val_accuracy: 0.7340 - val_loss: 1.3487
# Epoch 452/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1568 - val_accuracy: 0.7387 - val_loss: 1.3358
# Epoch 453/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1551 - val_accuracy: 0.7340 - val_loss: 1.3544
# Epoch 454/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1544 - val_accuracy: 0.7363 - val_loss: 1.3368
# Epoch 455/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.1546 - val_accuracy: 0.7316 - val_loss: 1.3511
# Epoch 456/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9591 - loss: 0.1545 - val_accuracy: 0.7363 - val_loss: 1.3510
# Epoch 457/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1533 - val_accuracy: 0.7387 - val_loss: 1.3526
# Epoch 458/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9622 - loss: 0.1541 - val_accuracy: 0.7435 - val_loss: 1.3620
# Epoch 459/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9561 - loss: 0.1530 - val_accuracy: 0.7340 - val_loss: 1.3628
# Epoch 460/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9602 - loss: 0.1548 - val_accuracy: 0.7292 - val_loss: 1.3734
# Epoch 461/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1521 - val_accuracy: 0.7458 - val_loss: 1.3611
# Epoch 462/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1526 - val_accuracy: 0.7458 - val_loss: 1.3615
# Epoch 463/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9602 - loss: 0.1531 - val_accuracy: 0.7316 - val_loss: 1.3836
# Epoch 464/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.1514 - val_accuracy: 0.7316 - val_loss: 1.3787
# Epoch 465/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9632 - loss: 0.1505 - val_accuracy: 0.7316 - val_loss: 1.3844
# Epoch 466/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9602 - loss: 0.1513 - val_accuracy: 0.7387 - val_loss: 1.3791
# Epoch 467/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9632 - loss: 0.1517 - val_accuracy: 0.7363 - val_loss: 1.3871
# Epoch 468/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9673 - loss: 0.1487 - val_accuracy: 0.7363 - val_loss: 1.3948
# Epoch 469/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.1520 - val_accuracy: 0.7292 - val_loss: 1.3955
# Epoch 470/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9622 - loss: 0.1505 - val_accuracy: 0.7363 - val_loss: 1.3946
# Epoch 471/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9632 - loss: 0.1475 - val_accuracy: 0.7363 - val_loss: 1.4033
# Epoch 472/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.1462 - val_accuracy: 0.7340 - val_loss: 1.3864
# Epoch 473/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9622 - loss: 0.1480 - val_accuracy: 0.7268 - val_loss: 1.4253
# Epoch 474/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9663 - loss: 0.1480 - val_accuracy: 0.7268 - val_loss: 1.4180
# Epoch 475/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9632 - loss: 0.1472 - val_accuracy: 0.7363 - val_loss: 1.4215
# Epoch 476/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9591 - loss: 0.1467 - val_accuracy: 0.7245 - val_loss: 1.4266
# Epoch 477/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9591 - loss: 0.1470 - val_accuracy: 0.7292 - val_loss: 1.4283
# Epoch 478/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9602 - loss: 0.1484 - val_accuracy: 0.7245 - val_loss: 1.4295
# Epoch 479/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9642 - loss: 0.1444 - val_accuracy: 0.7292 - val_loss: 1.4245
# Epoch 480/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9632 - loss: 0.1429 - val_accuracy: 0.7245 - val_loss: 1.4507
# Epoch 481/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9622 - loss: 0.1458 - val_accuracy: 0.7292 - val_loss: 1.4329
# Epoch 482/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9673 - loss: 0.1425 - val_accuracy: 0.7316 - val_loss: 1.4370
# Epoch 483/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9673 - loss: 0.1428 - val_accuracy: 0.7245 - val_loss: 1.4314
# Epoch 484/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9632 - loss: 0.1426 - val_accuracy: 0.7245 - val_loss: 1.4544
# Epoch 485/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.1442 - val_accuracy: 0.7292 - val_loss: 1.4480
# Epoch 486/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9591 - loss: 0.1448 - val_accuracy: 0.7316 - val_loss: 1.4450
# Epoch 487/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.1425 - val_accuracy: 0.7268 - val_loss: 1.4524
# Epoch 488/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9653 - loss: 0.1433 - val_accuracy: 0.7268 - val_loss: 1.4652
# Epoch 489/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9622 - loss: 0.1419 - val_accuracy: 0.7197 - val_loss: 1.4861
# Epoch 490/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9663 - loss: 0.1389 - val_accuracy: 0.7245 - val_loss: 1.4766
# Epoch 491/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.1404 - val_accuracy: 0.7363 - val_loss: 1.4653
# Epoch 492/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.1394 - val_accuracy: 0.7245 - val_loss: 1.4900
# Epoch 493/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9632 - loss: 0.1399 - val_accuracy: 0.7221 - val_loss: 1.4876
# Epoch 494/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9704 - loss: 0.1398 - val_accuracy: 0.7268 - val_loss: 1.4805
# Epoch 495/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9694 - loss: 0.1394 - val_accuracy: 0.7221 - val_loss: 1.4852
# Epoch 496/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.1392 - val_accuracy: 0.7268 - val_loss: 1.4936
# Epoch 497/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9673 - loss: 0.1382 - val_accuracy: 0.7245 - val_loss: 1.4896
# Epoch 498/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9673 - loss: 0.1387 - val_accuracy: 0.7245 - val_loss: 1.5050
# Epoch 499/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9663 - loss: 0.1387 - val_accuracy: 0.7245 - val_loss: 1.5017
# Epoch 500/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9632 - loss: 0.1410 - val_accuracy: 0.7292 - val_loss: 1.5010
# CPU times: user 3min 49s, sys: 55.7 s, total: 4min 44s
# Wall time: 3min 19s

# %% [markdown]
# #### Your Neural Network's Performance
#
# Evaluate the model on the testing set and print the accuracy.

# %%
# YOUR CODE HERE

results = model.evaluate(X_test_scaled, y_test, verbose=0)


results
# Out:
# [1.6746524572372437, 0.7166666388511658]

# %% [markdown]
# #### Learnings About Number of Epochs
#
# Plot the history of the model with the `plot_loss_accuracy()` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))

    # --- LOSS ---

    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])

    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')

    ax[0].set_ylim((0,3))

    ax[0].legend(['Train', 'Val'], loc='best')

    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)

    # --- ACCURACY

    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])

    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')

    ax[1].legend(['Train', 'Val'], loc='best')

    ax[1].set_ylim((0,1))

    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)

    if title:
        fig.suptitle(title)

# %%
# YOUR CODE HERE
plot_loss_accuracy(history)

# %% [markdown]
# 👩🏻‍🏫 We clearly see that **the number of epochs we choose has a strong influence on the final results**:
#
# **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
# - The algorithm is not optimal as its Loss Function has **not converged yet**
# - It hasn't learned enough from the training data
#
# **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
# - Our Neural Network has **learned too much** from the training data, including its noisy information
# - The algorithm **does not generalize well** on test data
#
# 🚦 Basically, what we want to do is stop the algorithm **when the validation loss is minimal** (or when the validation metrics are maximal)

# %% [markdown]
# #### Early Stopping
#
# 🧑🏻‍🏫 Let's introduce the **Early Stopping** criterion.
#
# The Early Stopping criterion is a way to **automatically stop the training of the algorithm** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ **How does it work?**
#
# The model will pay attention to the **<font color=green>loss of the validation set</font>**. If <font color=green>it</font> starts increasing again 📈 while the <font color=blue>loss of the training set</font> keeps decreasing 📉, it is a good sign that the model is overfitting and the training should be stopped!
#
#
# <img src="validation_set.png" alt="Validation set" width=450/>

# %% [markdown]
# ##### Observing the Early Stopping Criterion
#
# Run the following code and plot the history.

# %%
# %%time

es = EarlyStopping()

model = initialize_model()

# Fit the model on the train data
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1,
    callbacks=[es] # This will call the Early Stopping Criterion for each epoch
)
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1982 - loss: 2.0347 - val_accuracy: 0.2613 - val_loss: 1.9625
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3075 - loss: 1.8969 - val_accuracy: 0.3515 - val_loss: 1.8442
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4045 - loss: 1.7459 - val_accuracy: 0.4727 - val_loss: 1.6669
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5475 - loss: 1.5218 - val_accuracy: 0.5677 - val_loss: 1.4408
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6221 - loss: 1.2892 - val_accuracy: 0.6105 - val_loss: 1.2440
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6456 - loss: 1.1006 - val_accuracy: 0.6580 - val_loss: 1.0844
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6946 - loss: 0.9674 - val_accuracy: 0.6841 - val_loss: 0.9666
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7140 - loss: 0.8685 - val_accuracy: 0.7126 - val_loss: 0.8764
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7385 - loss: 0.7987 - val_accuracy: 0.7292 - val_loss: 0.8091
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7518 - loss: 0.7468 - val_accuracy: 0.7601 - val_loss: 0.7585
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7651 - loss: 0.7038 - val_accuracy: 0.7720 - val_loss: 0.7135
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7630 - loss: 0.6697 - val_accuracy: 0.7838 - val_loss: 0.6847
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7712 - loss: 0.6432 - val_accuracy: 0.7886 - val_loss: 0.6590
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7824 - loss: 0.6191 - val_accuracy: 0.7933 - val_loss: 0.6317
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7865 - loss: 0.5986 - val_accuracy: 0.7933 - val_loss: 0.6131
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7906 - loss: 0.5796 - val_accuracy: 0.7957 - val_loss: 0.5985
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7906 - loss: 0.5682 - val_accuracy: 0.7933 - val_loss: 0.5878
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7988 - loss: 0.5594 - val_accuracy: 0.8052 - val_loss: 0.5759
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7988 - loss: 0.5466 - val_accuracy: 0.8076 - val_loss: 0.5683
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8008 - loss: 0.5376 - val_accuracy: 0.7981 - val_loss: 0.5642
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8018 - loss: 0.5308 - val_accuracy: 0.8029 - val_loss: 0.5584
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8039 - loss: 0.5259 - val_accuracy: 0.8052 - val_loss: 0.5546
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8049 - loss: 0.5199 - val_accuracy: 0.8029 - val_loss: 0.5520
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8121 - loss: 0.5134 - val_accuracy: 0.8052 - val_loss: 0.5497
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8080 - loss: 0.5117 - val_accuracy: 0.8029 - val_loss: 0.5485
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8161 - loss: 0.5040 - val_accuracy: 0.8052 - val_loss: 0.5445
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8131 - loss: 0.5033 - val_accuracy: 0.8052 - val_loss: 0.5440
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8161 - loss: 0.4988 - val_accuracy: 0.8076 - val_loss: 0.5403
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8090 - loss: 0.4974 - val_accuracy: 0.8029 - val_loss: 0.5414
# CPU times: user 21.2 s, sys: 4.58 s, total: 25.8 s
# Wall time: 19.1 s

# %% [markdown]
# ##### Evaluate the ES Model
#
# _(also look at the historical losses)_

# %%
# YOUR CODE HERE
results = model.evaluate(X_test_scaled, y_test, verbose=0)

plot_loss_accuracy(history)

# %% [markdown]
# ❗ **The problem with strict Early Stopping** ❗
#
# The problem with this type of approach is that as soon as the loss of the validation set increases, the model stops. However, as a Neural Network's convergence is stochastic, the loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a `patience` keyword that defines how many **consecutive epochs without any loss decrease** are allowed in the validation set before we stop the training procedure.
#
# Use the `EarlyStopping` criterion with a patience term of 30 epochs, plot the results, and print the accuracy on the testing set

# %%
# YOUR CODE HERE
es = EarlyStopping(patience=30)

model = initialize_model()

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1,
    callbacks=[es]
)

results = model.evaluate(X_test_scaled, y_test, verbose=0)


plot_loss_accuracy(history)
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1450 - loss: 2.1388 - val_accuracy: 0.2185 - val_loss: 1.9952
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2533 - loss: 1.9555 - val_accuracy: 0.3468 - val_loss: 1.8474
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3555 - loss: 1.7934 - val_accuracy: 0.4252 - val_loss: 1.6732
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4321 - loss: 1.6099 - val_accuracy: 0.4727 - val_loss: 1.5002
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5240 - loss: 1.4261 - val_accuracy: 0.5558 - val_loss: 1.3234
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6251 - loss: 1.2528 - val_accuracy: 0.6508 - val_loss: 1.1689
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6752 - loss: 1.1011 - val_accuracy: 0.6936 - val_loss: 1.0312
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7140 - loss: 0.9788 - val_accuracy: 0.7363 - val_loss: 0.9280
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7273 - loss: 0.8901 - val_accuracy: 0.7411 - val_loss: 0.8521
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7283 - loss: 0.8222 - val_accuracy: 0.7625 - val_loss: 0.7880
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7559 - loss: 0.7655 - val_accuracy: 0.7696 - val_loss: 0.7463
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7640 - loss: 0.7228 - val_accuracy: 0.7625 - val_loss: 0.7162
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7753 - loss: 0.6873 - val_accuracy: 0.7743 - val_loss: 0.6834
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7743 - loss: 0.6586 - val_accuracy: 0.7743 - val_loss: 0.6679
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7773 - loss: 0.6348 - val_accuracy: 0.7767 - val_loss: 0.6466
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7855 - loss: 0.6161 - val_accuracy: 0.7838 - val_loss: 0.6310
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7845 - loss: 0.6004 - val_accuracy: 0.7910 - val_loss: 0.6144
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7957 - loss: 0.5874 - val_accuracy: 0.7862 - val_loss: 0.6103
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7967 - loss: 0.5747 - val_accuracy: 0.7910 - val_loss: 0.5998
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7926 - loss: 0.5620 - val_accuracy: 0.7981 - val_loss: 0.5893
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7998 - loss: 0.5544 - val_accuracy: 0.8029 - val_loss: 0.5825
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8018 - loss: 0.5449 - val_accuracy: 0.7862 - val_loss: 0.5816
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8059 - loss: 0.5375 - val_accuracy: 0.7933 - val_loss: 0.5733
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8059 - loss: 0.5342 - val_accuracy: 0.7886 - val_loss: 0.5697
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8090 - loss: 0.5268 - val_accuracy: 0.7886 - val_loss: 0.5689
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8100 - loss: 0.5216 - val_accuracy: 0.7910 - val_loss: 0.5619
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8141 - loss: 0.5139 - val_accuracy: 0.8005 - val_loss: 0.5580
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8110 - loss: 0.5095 - val_accuracy: 0.7957 - val_loss: 0.5558
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8172 - loss: 0.5075 - val_accuracy: 0.7933 - val_loss: 0.5561
# Epoch 30/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8192 - loss: 0.5008 - val_accuracy: 0.7933 - val_loss: 0.5572
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8192 - loss: 0.4956 - val_accuracy: 0.7957 - val_loss: 0.5525
# Epoch 32/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8161 - loss: 0.4979 - val_accuracy: 0.7981 - val_loss: 0.5542
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8202 - loss: 0.4897 - val_accuracy: 0.7838 - val_loss: 0.5524
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8223 - loss: 0.4855 - val_accuracy: 0.7981 - val_loss: 0.5511
# Epoch 35/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8264 - loss: 0.4837 - val_accuracy: 0.7933 - val_loss: 0.5481
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8253 - loss: 0.4806 - val_accuracy: 0.7957 - val_loss: 0.5497
# Epoch 37/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8304 - loss: 0.4765 - val_accuracy: 0.8052 - val_loss: 0.5433
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4738 - val_accuracy: 0.7933 - val_loss: 0.5478
# Epoch 39/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8274 - loss: 0.4720 - val_accuracy: 0.7981 - val_loss: 0.5489
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8284 - loss: 0.4697 - val_accuracy: 0.8005 - val_loss: 0.5466
# Epoch 41/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8315 - loss: 0.4674 - val_accuracy: 0.7981 - val_loss: 0.5476
# Epoch 42/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8315 - loss: 0.4659 - val_accuracy: 0.7981 - val_loss: 0.5427
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8386 - loss: 0.4624 - val_accuracy: 0.8005 - val_loss: 0.5456
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8376 - loss: 0.4603 - val_accuracy: 0.7933 - val_loss: 0.5463
# Epoch 45/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8304 - loss: 0.4616 - val_accuracy: 0.8005 - val_loss: 0.5457
# Epoch 46/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8304 - loss: 0.4566 - val_accuracy: 0.7981 - val_loss: 0.5448
# Epoch 47/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8396 - loss: 0.4535 - val_accuracy: 0.7957 - val_loss: 0.5499
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8315 - loss: 0.4534 - val_accuracy: 0.7981 - val_loss: 0.5471
# Epoch 49/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8355 - loss: 0.4502 - val_accuracy: 0.7886 - val_loss: 0.5497
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8335 - loss: 0.4479 - val_accuracy: 0.7910 - val_loss: 0.5448
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8335 - loss: 0.4471 - val_accuracy: 0.7933 - val_loss: 0.5452
# Epoch 52/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8386 - loss: 0.4460 - val_accuracy: 0.7862 - val_loss: 0.5477
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8386 - loss: 0.4443 - val_accuracy: 0.8005 - val_loss: 0.5453
# Epoch 54/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8376 - loss: 0.4411 - val_accuracy: 0.7862 - val_loss: 0.5485
# Epoch 55/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8366 - loss: 0.4399 - val_accuracy: 0.7981 - val_loss: 0.5467
# Epoch 56/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8437 - loss: 0.4388 - val_accuracy: 0.7838 - val_loss: 0.5514
# Epoch 57/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8478 - loss: 0.4359 - val_accuracy: 0.7981 - val_loss: 0.5488
# Epoch 58/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8407 - loss: 0.4379 - val_accuracy: 0.7910 - val_loss: 0.5508
# Epoch 59/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8447 - loss: 0.4363 - val_accuracy: 0.7981 - val_loss: 0.5475
# Epoch 60/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.4349 - val_accuracy: 0.7910 - val_loss: 0.5570
# Epoch 61/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.4311 - val_accuracy: 0.7910 - val_loss: 0.5501
# Epoch 62/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8437 - loss: 0.4318 - val_accuracy: 0.7910 - val_loss: 0.5521
# Epoch 63/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8458 - loss: 0.4267 - val_accuracy: 0.7886 - val_loss: 0.5516
# Epoch 64/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8417 - loss: 0.4254 - val_accuracy: 0.7862 - val_loss: 0.5514
# Epoch 65/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8427 - loss: 0.4257 - val_accuracy: 0.7838 - val_loss: 0.5537
# Epoch 66/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8519 - loss: 0.4227 - val_accuracy: 0.7910 - val_loss: 0.5504
# Epoch 67/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.4229 - val_accuracy: 0.7886 - val_loss: 0.5557
# Epoch 68/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.4220 - val_accuracy: 0.7838 - val_loss: 0.5566
# Epoch 69/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8498 - loss: 0.4193 - val_accuracy: 0.7886 - val_loss: 0.5593
# Epoch 70/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.4188 - val_accuracy: 0.7910 - val_loss: 0.5567
# Epoch 71/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8427 - loss: 0.4204 - val_accuracy: 0.7838 - val_loss: 0.5585
# Epoch 72/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8498 - loss: 0.4149 - val_accuracy: 0.7815 - val_loss: 0.5588

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# - 📉 The model continues to converge even though its Loss Function had some consecutive loss increases/decreases w.r.t. to the number of epochs
# - 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand, and there is no general rule of thumb
# - 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     - 🤞 your Neural Network should theoretically still stop training before the end (not always the case if your number of epochs is too low)
#     - ❗️ your validation loss will increase again after reaching a minimum value, but ideally, you want it to be as low as possible; the validation loss potentially reaches a minimum for certain weights at a certain epoch
#         - 🤔 How to find these weights?
#
# 📚 The `EarlyStopping` criterion enables you to:
# - stop the convergence
# - restore the best weights of the NN when it had the lowest error level (or the best score) on the validation set, thanks to `restore_best_weights = True` (set to `False` by default)

# %% [markdown]
# ##### Restoring the Best Weights of a Model
#
# - Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# - Plot the loss and accuracy
# - Print the accuracy on the testing set

# %%
# YOUR CODE HERE
es = EarlyStopping(
    patience=30,
    restore_best_weights=True
)

model = initialize_model()

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=1,
    callbacks=[es]
)

results = model.evaluate(X_test_scaled, y_test, verbose=0)

plot_loss_accuracy(history)
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1777 - loss: 2.0407 - val_accuracy: 0.2352 - val_loss: 1.9636
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3156 - loss: 1.8853 - val_accuracy: 0.3468 - val_loss: 1.8086
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4035 - loss: 1.6895 - val_accuracy: 0.4228 - val_loss: 1.6136
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5005 - loss: 1.4756 - val_accuracy: 0.5392 - val_loss: 1.4124
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5628 - loss: 1.2849 - val_accuracy: 0.6128 - val_loss: 1.2344
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6210 - loss: 1.1263 - val_accuracy: 0.6485 - val_loss: 1.0741
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6905 - loss: 0.9805 - val_accuracy: 0.7102 - val_loss: 0.9252
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7242 - loss: 0.8600 - val_accuracy: 0.7268 - val_loss: 0.8104
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7497 - loss: 0.7725 - val_accuracy: 0.7553 - val_loss: 0.7277
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7651 - loss: 0.7094 - val_accuracy: 0.7553 - val_loss: 0.6665
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7722 - loss: 0.6629 - val_accuracy: 0.7577 - val_loss: 0.6292
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7794 - loss: 0.6329 - val_accuracy: 0.7720 - val_loss: 0.6056
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7773 - loss: 0.6083 - val_accuracy: 0.7720 - val_loss: 0.5849
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7886 - loss: 0.5861 - val_accuracy: 0.7815 - val_loss: 0.5732
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7967 - loss: 0.5728 - val_accuracy: 0.8005 - val_loss: 0.5560
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8018 - loss: 0.5583 - val_accuracy: 0.7910 - val_loss: 0.5514
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8018 - loss: 0.5495 - val_accuracy: 0.7933 - val_loss: 0.5492
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8110 - loss: 0.5405 - val_accuracy: 0.7957 - val_loss: 0.5432
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8110 - loss: 0.5348 - val_accuracy: 0.7933 - val_loss: 0.5434
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8172 - loss: 0.5272 - val_accuracy: 0.7957 - val_loss: 0.5387
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8141 - loss: 0.5204 - val_accuracy: 0.7910 - val_loss: 0.5400
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8161 - loss: 0.5170 - val_accuracy: 0.7910 - val_loss: 0.5372
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8161 - loss: 0.5119 - val_accuracy: 0.8029 - val_loss: 0.5326
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8182 - loss: 0.5080 - val_accuracy: 0.7957 - val_loss: 0.5383
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8264 - loss: 0.5070 - val_accuracy: 0.8052 - val_loss: 0.5352
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8274 - loss: 0.5010 - val_accuracy: 0.7886 - val_loss: 0.5366
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8274 - loss: 0.4966 - val_accuracy: 0.7957 - val_loss: 0.5344
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8264 - loss: 0.4939 - val_accuracy: 0.8005 - val_loss: 0.5352
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8253 - loss: 0.4919 - val_accuracy: 0.8076 - val_loss: 0.5338
# Epoch 30/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8284 - loss: 0.4900 - val_accuracy: 0.7910 - val_loss: 0.5396
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8284 - loss: 0.4876 - val_accuracy: 0.8005 - val_loss: 0.5351
# Epoch 32/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8284 - loss: 0.4892 - val_accuracy: 0.7862 - val_loss: 0.5388
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8325 - loss: 0.4849 - val_accuracy: 0.7910 - val_loss: 0.5393
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8335 - loss: 0.4809 - val_accuracy: 0.7981 - val_loss: 0.5388
# Epoch 35/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8325 - loss: 0.4778 - val_accuracy: 0.7957 - val_loss: 0.5386
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8355 - loss: 0.4779 - val_accuracy: 0.7886 - val_loss: 0.5418
# Epoch 37/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4739 - val_accuracy: 0.8029 - val_loss: 0.5362
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8376 - loss: 0.4736 - val_accuracy: 0.7886 - val_loss: 0.5403
# Epoch 39/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4716 - val_accuracy: 0.7886 - val_loss: 0.5404
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8345 - loss: 0.4698 - val_accuracy: 0.7933 - val_loss: 0.5454
# Epoch 41/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8355 - loss: 0.4687 - val_accuracy: 0.8005 - val_loss: 0.5406
# Epoch 42/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8355 - loss: 0.4666 - val_accuracy: 0.8005 - val_loss: 0.5362
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8396 - loss: 0.4653 - val_accuracy: 0.7910 - val_loss: 0.5428
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8386 - loss: 0.4659 - val_accuracy: 0.7886 - val_loss: 0.5421
# Epoch 45/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8407 - loss: 0.4619 - val_accuracy: 0.7886 - val_loss: 0.5408
# Epoch 46/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8355 - loss: 0.4629 - val_accuracy: 0.7886 - val_loss: 0.5447
# Epoch 47/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8417 - loss: 0.4609 - val_accuracy: 0.7862 - val_loss: 0.5392
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8407 - loss: 0.4568 - val_accuracy: 0.7957 - val_loss: 0.5421
# Epoch 49/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8427 - loss: 0.4542 - val_accuracy: 0.7957 - val_loss: 0.5416
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8427 - loss: 0.4527 - val_accuracy: 0.7886 - val_loss: 0.5430
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8447 - loss: 0.4517 - val_accuracy: 0.7838 - val_loss: 0.5446
# Epoch 52/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8417 - loss: 0.4497 - val_accuracy: 0.8005 - val_loss: 0.5436
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8458 - loss: 0.4475 - val_accuracy: 0.7862 - val_loss: 0.5476

# %% [markdown]
# 🥡 **Takeaways from the Early Stopping criterion:**
#
# - You can look at the 📚 [**Early Stopping documentation**](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
# - You no longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch Size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# #### Playing with the Batch Size
#
# Let's run the previous model with **different batch sizes** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL

for batch_size in [1, 4, 32]:

    model = initialize_model()

    es = EarlyStopping(patience=20, restore_best_weights=True)

    history = model.fit(
        X_train_scaled,
        y_train,
        validation_split=0.3,
        epochs=500,
        batch_size=batch_size,
        verbose=0,
        callbacks=[es]
    )

    results = model.evaluate(X_test_scaled, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is {results[1]:.2f}')
# Out:
# CPU times: user 3min 33s, sys: 57.5 s, total: 4min 30s
# Wall time: 2min 56s

# %% [markdown]
# #### ❓Question: Impact of the Batch Size on the Convergence of a Neural Network
#
# Look at the oscillations of the accuracy and the loss according to the batch size number.
#
# Is this coherent with what we saw when playing with the TensorFlow Playground?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### ❓Question: Number of Parameter Updates
#
# How many weight optimizations are done within one epoch (considering the number of observations and the batch size)? Does one epoch have more weight updates with a large or with a small batch size?

# %% [markdown]
# > Your answer here

# %% [markdown]
# #### Explanations
#
# Copy and paste this code into a new cell, run it, and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(
#     X_train_scaled,
#     y_train,
#     validation_split = 0.3,
#     epochs = epochs,
#     batch_size = batch_size,
#     verbose = 1
# )
# ```
#
#
# <u><b>Number of parameter updates:</b></u>
#
# - There are 1400 rows in the training set:
#     - $ 70 \% \times 1400 = 980 $ rows are used as the training set within the training set
#     - $ 30 \% \times 1400 = 420 $ rows are used as the validation set
# - For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
# - Without the Early Stopping Criterion, we will have _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations overall
#
# <u><b>Impact of the batch size:</b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
# $ \implies $ Parameters will be updated more frequently
# $ \implies $ We may need fewer epochs
#
# _(but we also don't care too much about the number of epochs if we use an Early Stopping Criterion with a patience term anyway)_

# %%
batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)
# Out:
# Epoch 1/2
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2932 - loss: 1.9765 - val_accuracy: 0.2874 - val_loss: 1.9341
# Epoch 2/2
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4382 - loss: 1.7583 - val_accuracy: 0.4014 - val_loss: 1.7542

# %% [markdown]
# ### (2.3) Regularization
#
# ❗️**Neural Networks with complex architectures can quickly lead to overfitting** (_too many layers and/or neurons_)❗️
#
# 🔥 But since Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2, or L1-L2 penalties!
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons; as in Machine Learning, these penalties are called **`Regularizers`**.
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">See `tf.keras.regularizers`</a>

# %% [markdown]
# #### Observing Overfitting Before Regularizing
#
# First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. To that purpose, let's not use any Early Stopping criterion.
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = Sequential()
model.add(Input(shape=(10,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model Compilation
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 3. Training
history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=300,           # Notice that we are not using any Early Stopping Criterion
    batch_size=16,
    verbose=0
)

# 4. Evaluation
results_train = model.evaluate(X_train_scaled, y_train, verbose=0)
results_test = model.evaluate(X_test_scaled, y_test, verbose=0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.76...
# ...whereas the accuracy on the training set is 0.87!

# %% [markdown]
# ☝️ In our "over-parameterized network", some neurons became **too specific for the given training data**, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting!

# %% [markdown]
# #### Studying the Impact of Regularization on the Neural Network
#
# Change the previous code to integrate an L2 or L1 regularizer into your Dense Layers.

# %%
# YOUR CODE HERE
model = Sequential()
model.add(Input(shape=(10,)))
model.add(layers.Dense(25, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(10, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(8, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=300,
    batch_size=16,
    verbose=0
)

results_train = model.evaluate(X_train_scaled, y_train, verbose=0)
results_test = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f'The accuracy on the testing set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')

plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.77...
# ...whereas the accuracy on the training set is 0.84!

# %% [markdown]
# ### (2.4) Dropout Layers

# %% [markdown]
# #### Introduction to Dropout Layers
#
# The role of a Dropout Layer is to randomly cancel the output of some neurons during the training phase, it prevents the network from getting too specific for the input data.
#
# Dropout Layers
# - ensure that no neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled
# - force the information of an input to be spread across multiple neurons instead of only one specific neuron
# - are super straightforward to code 👌
#   - but what is going on _under the hood_? 👩🏻‍🏫

# %% [markdown]
# #### Optional Reading
#
# <details>
#     <summary>Click here for further explanations about Dropout Layers</summary>
#
# 🤔 Remember what we said about neurons becoming **too specific**?
#
# **`BEGIN_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
#
# ---
#
# ⚽️  **A Football Analogy:**
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench. Why?
# - The coach may want to substitute injured or tired players during the game
# - The team may be
#     - losing the game and willing to substitute a midfielder with a more **versatile player** who can be more offensive (= **mix of** midfielder/attacker roles)
#     - winning the game and would like to secure the result by replacing a midfielder with a more **versatile player** who can be more defensive (= **mix of** midfielder/defense roles)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, where it would be advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing.**
#
# 🧑🏻‍🏫 How do Dropout Layers work?
#
# 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the **selected neurons** will have their weights **temporarily set to 0** , which has the following consequences:
# 1. A neuron computed at layer $k + 1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k + 1$
# 2. Once a batch of data points has been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer have been optimized/updated (**backward propagation** with the **Adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#    - 80% of the weights; the ones that were updated
#    - 20% of the weights; the ones that were previously ignored and had their values **temporarily** set to 0
#
# Based on these weights, we will go through this Dropout Layer again, which is going to temporarily ignore another 20% of the weights of a given layer. Be careful, the selection of this 20% is random, so the weights that will be ignored this time won't necessarily be the same as before!
#
# 👉 Think about the **Dropout rate** as a **sampling with replacement**
#
# 👉 By **randomly shutting down** different neurons at different epochs, we force the data points to be **analyzed by different neurons**. At the end of the day, these neurons will become **more versatile** instead of over-specializing!
#
# ---
#
# **`END_EXPLANATIONS_ABOUT_DROPOUT_LAYERS`**
# </details>

# %% [markdown]
# #### Studying the Impact of Dropout Layers on the Neural Network
#
# Include some Dropout layers in the architecture of your original model _(don't add regularizers here)_.
#
# What can you observe regarding the convergence of your model? What about its ability to generalize?

# %%
# YOUR CODE HERE
model = Sequential()
model.add(Input(shape=(10,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(8, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

es = EarlyStopping(
    patience=30,
    restore_best_weights=True
)

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.3,
    epochs=500,
    batch_size=16,
    verbose=0,
    callbacks=[es]
)

results_train = model.evaluate(X_train_scaled, y_train, verbose=0)
results_test = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"The accuracy on the testing set is {results_test[1]:.2f}...")
print(f"...whereas the accuracy on the training set is {results_train[1]:.2f}!")

plot_loss_accuracy(history)
# Out:
# The accuracy on the testing set is 0.78...
# ...whereas the accuracy on the training set is 0.82!

# %% [markdown]
# ## (3) Conclusions
#
# - ❗️ If you train a Neural Network too much (too many layers, too many neurons, and/or too many epochs), it will overfit very quickly
# - 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization, and Dropout Layers
# - ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where your model would underfit the dataset!
# - 🆗 You could potentially look at the batch size but we usually use 16 or 32; and as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="500">

# %% [markdown]
# ## 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
